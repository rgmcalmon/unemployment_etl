# %% [markdown]
# ## Extraction.ipynb
# This extracts dataframes from three different data sources
# 1. `states.csv`: the data which maps state names to state abbreviations
# 2. `crime_data_w_population_and_crime_rate.csv`: the county data on crime rates based on crime reports from 2013
# 3. `result.json`: yearly/monthly data on unemployment by county in the USA

# %%
import pandas as pd
import json

# %% [markdown]
# ### State-to-abbreviation map
# This is straightforward

# %%
state_abb = pd.read_csv("raw_data/states.csv")
state_abb.head()
# Out:
#         State Abbreviation
# 0     Alabama           AL
# 1      Alaska           AK
# 2     Arizona           AZ
# 3    Arkansas           AR
# 4  California           CA

# %% [markdown]
# ### Crime Rate Dataframe
# Also straightforward to extract

# %%
crime_rate_df = pd.read_csv("raw_data/crime_data_w_population_and_crime_rate.csv")
crime_rate_df.head()
# Out:
#              county_name  crime_rate_per_100000  index  EDITION  PART  IDNO  \
# 0     St. Louis city, MO            1791.995377      1        1     4  1612
# 1  Crittenden County, AR            1754.914968      2        1     4   130
# 2   Alexander County, IL            1664.700485      3        1     4   604
# 3      Kenedy County, TX            1456.310680      4        1     4  2681
# 4     De Soto Parish, LA            1447.402430      5        1     4  1137
#
#    CPOPARST  CPOPCRIM  AG_ARRST  AG_OFF    ...     RAPE  ROBBERY  AGASSLT  \
# 0    318667    318667        15      15    ...      200     1778     3609
# 1     50717     50717         4       4    ...       38      165      662
# 2      8040      8040         2       2    ...        2        5      119
# 3       444       444         1       1    ...        3        1        2
# 4     26971     26971         3       3    ...        4       17      368
#
#    BURGLRY  LARCENY  MVTHEFT  ARSON  population  FIPS_ST  FIPS_CTY
# 0     4995    13791     3543    464      318416       29       510
# 1     1482     1753      189     28       49746        5        35
# 2       82      184       12      2        7629       17         3
# 3        5        4        4      0         412       48       261
# 4      149      494       60      0       27083       22        31
#
# [5 rows x 24 columns]

# %% [markdown]
# ### Unemployment JSON
# This is a little trickier since we cannot directly load into a pandas dataframe using a library function; we have to construct it in a more hands-on way. Note here that we only get annual data from the year 2013.

# %%
with open('raw_data/result.json') as json_file:
    data = json.load(json_file)

unemployment_df = pd.DataFrame(columns=['county', 'state', 'unemployment_rate'])

for state, v in data['2013']['Annual'].items():
    for county, rate in v['Unemployment Rate'].items():
        unemployment_df = unemployment_df.append({'county': county, 'state': state, 'unemployment_rate': rate}, ignore_index=True)

unemployment_df.head()
# Out:
#            county    state  unemployment_rate
# 0  Autauga County  Alabama                6.2
# 1  Baldwin County  Alabama                6.6
# 2  Barbour County  Alabama               10.3
# 3     Bibb County  Alabama                7.9
# 4   Blount County  Alabama                6.3

# %% [markdown]
# ## Clean up County/State data in preparation for join operation

# %% [markdown]
# 1. Split `county_name` column into two columns in crime rate dataframe
# 2. Convert county names to lower case for both unemployment and crime rate dataframes
# 3. Replace "st." with "saint" and "ste." with "sainte" in crime rate dataframe
# 4. Remove apostrophes in crime rate county names
# 5. Replace "debaca" with "de baca" and "mc kean" with "mckean" in the unemployment crime rate county names
# 6. Change state names to abbreviations in unemployment dataframe

# %%
### 1
crime_rate_df['county'] = crime_rate_df['county_name'].apply(lambda s: s[:-4])
crime_rate_df['state'] = crime_rate_df['county_name'].apply(lambda s: s[-2:])

crime_rate_df = crime_rate_df.drop(labels=['county_name'], axis=1)

# %%
### 2
crime_rate_df['county'] = crime_rate_df['county'].apply(lambda s: s.lower())
unemployment_df['county'] = unemployment_df['county'].apply(lambda s: s.lower())

# %%
### 3
crime_rate_df['county'] = crime_rate_df['county'].apply(lambda s: s.replace('st.', 'saint').replace('ste.', 'sainte'))

# %%
### 4
crime_rate_df['county'] = crime_rate_df['county'].apply(lambda s: s.replace("'", ""))

# %%
### 5
unemployment_df['county'] = unemployment_df['county'].apply(lambda s: s.replace('debaca', 'de baca').replace('mc kean', 'mckean'))

# %%
### 6
unemployment_df['state'] = unemployment_df['state'].apply(lambda s: state_abb[state_abb.State == s]['Abbreviation'].values[0])

# %%
crime_rate_df.head()
# Out:
#    crime_rate_per_100000  index  EDITION  PART  IDNO  CPOPARST  CPOPCRIM  \
# 0            1791.995377      1        1     4  1612    318667    318667
# 1            1754.914968      2        1     4   130     50717     50717
# 2            1664.700485      3        1     4   604      8040      8040
# 3            1456.310680      4        1     4  2681       444       444
# 4            1447.402430      5        1     4  1137     26971     26971
#
#    AG_ARRST  AG_OFF  COVIND  ...    AGASSLT  BURGLRY  LARCENY  MVTHEFT  ARSON  \
# 0        15      15   100.0  ...       3609     4995    13791     3543    464
# 1         4       4   100.0  ...        662     1482     1753      189     28
# 2         2       2   100.0  ...        119       82      184       12      2
# 3         1       1   100.0  ...          2        5        4        4      0
# 4         3       3   100.0  ...        368      149      494       60      0
#
#    population  FIPS_ST  FIPS_CTY             county  state
# 0      318416       29       510   saint louis city     MO
# 1       49746        5        35  crittenden county     AR
# 2        7629       17         3   alexander county     IL
# 3         412       48       261      kenedy county     TX
# 4       27083       22        31     de soto parish     LA
#
# [5 rows x 25 columns]

# %%
unemployment_df.head()
# Out:
#            county state  unemployment_rate
# 0  autauga county    AL                6.2
# 1  baldwin county    AL                6.6
# 2  barbour county    AL               10.3
# 3     bibb county    AL                7.9
# 4   blount county    AL                6.3

# %%
crime_rate_joined_df = pd.merge(crime_rate_df, unemployment_df, on=['county', 'state'])
crime_rate_joined_df
# Out:
#       crime_rate_per_100000  index  EDITION  PART  IDNO  CPOPARST  CPOPCRIM  \
# 0               1791.995377      1        1     4  1612    318667    318667
# 1               1754.914968      2        1     4   130     50717     50717
# 2               1664.700485      3        1     4   604      8040      8040
# 3               1456.310680      4        1     4  2681       444       444
# 4               1447.402430      5        1     4  1137     26971     26971
# 5               1419.537569      6        1     4  1227    625474    625474
# 6               1315.003752      7        1     4  2534    942807    942807
# 7               1253.437132      8        1     4  2377     28780     28780
# 8               1217.656012      9        1     4  1778      3947      3947
# 9               1165.583272     11        1     4  2359     32060     32060
# 10              1163.145839     12        1     4  1597     40941     40941
# 11              1150.296330     13        1     4  2320   1538957   1538957
# 12              1148.756725     14        1     4  1777      6822      6822
# 13              1140.226324     15        1     4  2366     71009     70499
# 14              1138.423830     16        1     4  2512     98988     99067
# 15              1129.513728     17        1     4  2474    635244    635244
# 16              1083.508119     18        1     4   753    911521    867596
# 17              1065.188284     19        1     4  1324   1800769   1793982
# 18              1026.623686     20        1     4  1545    839561    837636
# 19               998.709533     22        1     4  1575     18208     18208
# 20               974.016244     23        1     4  1145     33427     31544
# 21               959.916582     24        1     4   172    387762    387762
# 22               959.134320     25        1     4   147     76535     76535
# 23               956.177135     26        1     4   158     43925     43925
# 29          30      30   98.5058        ...             6105     8311
# ...        ...     ...       ...        ...              ...      ...
# 2793         2       1  100.0000        ...                0        1
# 2794         1       1  100.0000        ...                1        0
# 2795         1       1   91.6667        ...                0        1
# 2796         1       1  100.0000        ...                0        0
# 2797         1       1  100.0000        ...                0        0
# 2798         2       1  100.0000        ...                0        1
# 2799         2       2  100.0000        ...                0        1
# 2800         2       1  100.0000        ...                0        1
# 2801         1       1  100.0000        ...                0        0
# 2802         2       1  100.0000        ...                2        1
# 2803         2       1  100.0000        ...                1        2
# 2804         1       1  100.0000        ...                2        1
# 2805         2       2   88.0927        ...                5        3
# 2806         1       1  100.0000        ...                7        5
# 2807         1       1  100.0000        ...                3        7
# 2808         2       2  100.0000        ...                4        7
# 2809         2       2  100.0000        ...                2        8
# 2810         1       1  100.0000        ...                5        5
# 2811         1       1  100.0000        ...                2        4
# 2812         1       1  100.0000        ...                3        5
# 2813         1       1  100.0000        ...                3        5
# 2814         1       1  100.0000        ...                0        2
# 2815         2       2  100.0000        ...                0        4
# 2816         3       2  100.0000        ...                0        5
# 2817         2       2  100.0000        ...                3        2
# 2818         2       1  100.0000        ...                2        2
# 2819         3       1  100.0000        ...                4        0
# 2820         1       1  100.0000        ...                1        3
# 2821         2       2  100.0000        ...                1        2
# 2822         1       1  100.0000        ...                0        0
#
#       MVTHEFT  ARSON  population  FIPS_ST  FIPS_CTY                county  \
# 0        3543    464      318416       29       510      saint louis city
# 1         189     28       49746        5        35     crittenden county
# 2          12      2        7629       17         3      alexander county
# 3           4      0         412       48       261         kenedy county
# 4          60      0       27083       22        31        de soto parish
# 5        4009    251      622104       24       510        baltimore city
# 6        3233    435      939465       47       157         shelby county
# 7          67      5       28003       45        69       marlboro county
# 8           8      2        3942       32        29         storey county
# 9         105     12       31229       45        33         dillon county
# 10         39      8       39290       29       201          scott county
# 11       6401      0     1553165       42       101   philadelphia county
# 12          5      0        6877       32        27       pershing county
# 13        122     12       69723       45        47      greenwood county
# 14        180     27       98733       47       113        madison county
# 15       1418    100      658602       47        37       davidson county
# 16       4757    414      928281       18        97         marion county
# 17      15251    766     1775273       26       163          wayne county
# 18       4953    318      679996       29        95        jackson county
# 19         23      2       17823       29       155       pemiscot county
# 20         26      0       33367       22        47      iberville parish
# 21       1805    130      391284        5       119        pulaski county
# 22        255     44       73191        5        69      jefferson county
# 23        130      6       43402        5        91         miller county
# 24        142     23       70303       40       101       muskogee county
# 25         74     10       22119       45        11       barnwell county
# 26        218      1      125412       22       105     tangipahoa parish
# 27         92     12       32072       45        67         marion county
# 28        109     23       48491       40        19         carter county
# 29        936    313      415376       26        49        genesee county
# ...       ...    ...         ...      ...       ...                   ...
# 2793        0      0        5698       31        59       fillmore county
# 2794        0      0        1290       30        33       garfield county
# 2795        0      0        1437       46       119          sully county
# 2796        1      0         721        8        79        mineral county
# 2797        1      0        4041       46        45        edmunds county
# 2798        0      0        1902       31        69         garden county
# 2799        0      0        6895       31       173       thurston county
# 2800        0      0        7277       18       161          union county
# 2801        0      0        9982       46       121           todd county
# 2802        0      0        3586       48       271         kinney county
# 2803        0      0        4865       31        65         furnas county
# 2804        0      0        1121       30       109         wibaux county
# 2805        0      0        2754       38        51       mcintosh county
# 2806        0      0        2360       38         1          adams county
# 2807        2      0        6211       19       143        osceola county
# 2808        1      0        3093       48       421        sherman county
# 2809        1      0        3037       46       105        perkins county
# 2810        0      0         813        8        53       hinsdale county
# 2811        2      1        1334       46        21       campbell county
# 2812        0      0        1823       38        33  golden valley county
# 2813        0      0         867       16        33          clark county
# 2814        1      0        1537       48        45        briscoe county
# 2815        2      0        3366       38        31         foster county
# 2816        0      0       11305       31        13      box butte county
# 2817        0      0        1452       48       101         cottle county
# 2818        0      0        5994       18       115           ohio county
# 2819        1      0       21689       28       101         newton county
# 2820        1      0        2066       46        73        jerauld county
# 2821        0      0        2335       40        25       cimarron county
# 2822        0      0       12514       28        77       lawrence county
#
#       state  unemployment_rate
# 0        MO                8.4
# 1        AR                8.5
# 2        IL               12.7
# 3        TX                4.0
# 4        LA                8.9
# 5        MD                9.7
# 6        TN                8.8
# 7        SC               13.8
# 8        NV               11.5
# 9        SC               11.8
# 10       MO                7.1
# 11       PA               10.3
# 12       NV                8.7
# 13       SC                8.6
# 14       TN                8.1
# 15       TN                5.9
# 16       IN                8.5
# 17       MI               11.6
# 18       MO                7.7
# 19       MO               10.3
# 20       LA                8.4
# 21       AR                6.6
# 22       AR               10.4
# 23       AR                6.5
# 24       OK                6.5
# 25       SC               12.1
# 26       LA                8.1
# 27       SC               13.1
# 28       OK                5.3
# 29       MI                9.8
# ...     ...                ...
# 2793     NE                3.0
# 2794     MT                3.1
# 2795     SD                2.9
# 2796     CO                5.9
# 2797     SD                2.8
# 2798     NE                2.8
# 2799     NE                7.7
# 2800     IN                7.2
# 2801     SD                9.7
# 2802     TX                9.3
# 2803     NE                3.5
# 2804     MT                3.4
# 2805     ND                3.0
# 2806     ND                2.5
# 2807     IA                3.8
# 2808     TX                4.0
# 2809     SD                3.7
# 2810     CO                4.6
# 2811     SD                3.6
# 2812     ND                2.3
# 2813     ID                6.4
# 2814     TX                5.5
# 2815     ND                3.4
# 2816     NE                3.9
# 2817     TX                6.7
# 2818     IN                8.3
# 2819     MS                7.6
# 2820     SD                3.1
# 2821     OK                3.3
# 2822     MS                9.4
#
# [2823 rows x 26 columns]

# %%
crime_rate_joined_df = crime_rate_joined_df.drop(crime_rate_joined_df.columns[1], axis=1)
crime_rate_joined_df
# Out:
#       crime_rate_per_100000  EDITION  PART  IDNO  CPOPARST  CPOPCRIM  \
# 0               1791.995377        1     4  1612    318667    318667
# 1               1754.914968        1     4   130     50717     50717
# 2               1664.700485        1     4   604      8040      8040
# 3               1456.310680        1     4  2681       444       444
# 4               1447.402430        1     4  1137     26971     26971
# 5               1419.537569        1     4  1227    625474    625474
# 6               1315.003752        1     4  2534    942807    942807
# 7               1253.437132        1     4  2377     28780     28780
# 8               1217.656012        1     4  1778      3947      3947
# 9               1165.583272        1     4  2359     32060     32060
# 10              1163.145839        1     4  1597     40941     40941
# 11              1150.296330        1     4  2320   1538957   1538957
# 12              1148.756725        1     4  1777      6822      6822
# 13              1140.226324        1     4  2366     71009     70499
# 14              1138.423830        1     4  2512     98988     99067
# 15              1129.513728        1     4  2474    635244    635244
# 23           2       2  100.0000    415        ...              488     1597
# 24           6       6  100.0000    671        ...              878     1324
# 25           9       7  100.0000    211        ...              349      691
# 26           8       7   96.5846   1195        ...             2683     4262
# 27           9       7  100.0000    302        ...              771     1060
# 28           5       5  100.0000    451        ...              450     1327
# 29          30      30   98.5058   3833        ...             6105     8311
# ...        ...     ...       ...    ...        ...              ...      ...
# 2793         2       1  100.0000      0        ...                0        1
# 2794         1       1  100.0000      0        ...                1        0
# 2795         1       1   91.6667      0        ...                0        1
# 2796         1       1  100.0000      0        ...                0        0
# 2797         1       1  100.0000      0        ...                0        0
# 2798         2       1  100.0000      0        ...                0        1
# 2799         2       2  100.0000      0        ...                0        1
# 2800         2       1  100.0000      0        ...                0        1
# 2801         1       1  100.0000      0        ...                0        0
# 2802         2       1  100.0000      0        ...                2        1
# 2803         2       1  100.0000      0        ...                1        2
# 2804         1       1  100.0000      0        ...                2        1
# 2805         2       2   88.0927      0        ...                5        3
# 2806         1       1  100.0000      0        ...                7        5
# 2807         1       1  100.0000      0        ...                3        7
# 2808         2       2  100.0000      0        ...                4        7
# 2809         2       2  100.0000      0        ...                2        8
# 2810         1       1  100.0000      0        ...                5        5
# 2811         1       1  100.0000      0        ...                2        4
# 2812         1       1  100.0000      0        ...                3        5
# 2813         1       1  100.0000      0        ...                3        5
# 2814         1       1  100.0000      0        ...                0        2
# 2815         2       2  100.0000      0        ...                0        4
# 2816         3       2  100.0000      0        ...                0        5
# 2817         2       2  100.0000      0        ...                3        2
# 2818         2       1  100.0000      0        ...                2        2
# 2819         3       1  100.0000      0        ...                4        0
# 2820         1       1  100.0000      0        ...                1        3
# 2821         2       2  100.0000      0        ...                1        2
# 2822         1       1  100.0000      0        ...                0        0
#
#       MVTHEFT  ARSON  population  FIPS_ST  FIPS_CTY                county  \
# 0        3543    464      318416       29       510      saint louis city
# 1         189     28       49746        5        35     crittenden county
# 2          12      2        7629       17         3      alexander county
# 3           4      0         412       48       261         kenedy county
# 4          60      0       27083       22        31        de soto parish
# 5        4009    251      622104       24       510        baltimore city
# 6        3233    435      939465       47       157         shelby county
# 7          67      5       28003       45        69       marlboro county
# 8           8      2        3942       32        29         storey county
# 9         105     12       31229       45        33         dillon county
# 10         39      8       39290       29       201          scott county
# 11       6401      0     1553165       42       101   philadelphia county
# 12          5      0        6877       32        27       pershing county
# 13        122     12       69723       45        47      greenwood county
# 14        180     27       98733       47       113        madison county
# 15       1418    100      658602       47        37       davidson county
# 16       4757    414      928281       18        97         marion county
# 17      15251    766     1775273       26       163          wayne county
# 18       4953    318      679996       29        95        jackson county
# 19         23      2       17823       29       155       pemiscot county
# 20         26      0       33367       22        47      iberville parish
# 21       1805    130      391284        5       119        pulaski county
# 22        255     44       73191        5        69      jefferson county
# 23        130      6       43402        5        91         miller county
# 24        142     23       70303       40       101       muskogee county
# 25         74     10       22119       45        11       barnwell county
# 26        218      1      125412       22       105     tangipahoa parish
# 27         92     12       32072       45        67         marion county
# 28        109     23       48491       40        19         carter county
# 29        936    313      415376       26        49        genesee county
# ...       ...    ...         ...      ...       ...                   ...
# 2793        0      0        5698       31        59       fillmore county
# 2794        0      0        1290       30        33       garfield county
# 2795        0      0        1437       46       119          sully county
# 2796        1      0         721        8        79        mineral county
# 2797        1      0        4041       46        45        edmunds county
# 2798        0      0        1902       31        69         garden county
# 2799        0      0        6895       31       173       thurston county
# 2800        0      0        7277       18       161          union county
# 2801        0      0        9982       46       121           todd county
# 2802        0      0        3586       48       271         kinney county
# 2803        0      0        4865       31        65         furnas county
# 2804        0      0        1121       30       109         wibaux county
# 2805        0      0        2754       38        51       mcintosh county
# 2806        0      0        2360       38         1          adams county
# 2807        2      0        6211       19       143        osceola county
# 2808        1      0        3093       48       421        sherman county
# 2809        1      0        3037       46       105        perkins county
# 2810        0      0         813        8        53       hinsdale county
# 2811        2      1        1334       46        21       campbell county
# 2812        0      0        1823       38        33  golden valley county
# 2813        0      0         867       16        33          clark county
# 2814        1      0        1537       48        45        briscoe county
# 2815        2      0        3366       38        31         foster county
# 2816        0      0       11305       31        13      box butte county
# 2817        0      0        1452       48       101         cottle county
# 2818        0      0        5994       18       115           ohio county
# 2819        1      0       21689       28       101         newton county
# 2820        1      0        2066       46        73        jerauld county
# 2821        0      0        2335       40        25       cimarron county
# 2822        0      0       12514       28        77       lawrence county
#
#       state  unemployment_rate
# 0        MO                8.4
# 1        AR                8.5
# 2        IL               12.7
# 3        TX                4.0
# 4        LA                8.9
# 5        MD                9.7
# 6        TN                8.8
# 7        SC               13.8
# 8        NV               11.5
# 9        SC               11.8
# 10       MO                7.1
# 11       PA               10.3
# 12       NV                8.7
# 13       SC                8.6
# 14       TN                8.1
# 15       TN                5.9
# 16       IN                8.5
# 17       MI               11.6
# 18       MO                7.7
# 19       MO               10.3
# 20       LA                8.4
# 21       AR                6.6
# 22       AR               10.4
# 23       AR                6.5
# 24       OK                6.5
# 25       SC               12.1
# 26       LA                8.1
# 27       SC               13.1
# 28       OK                5.3
# 29       MI                9.8
# ...     ...                ...
# 2793     NE                3.0
# 2794     MT                3.1
# 2795     SD                2.9
# 2796     CO                5.9
# 2797     SD                2.8
# 2798     NE                2.8
# 2799     NE                7.7
# 2800     IN                7.2
# 2801     SD                9.7
# 2802     TX                9.3
# 2803     NE                3.5
# 2804     MT                3.4
# 2805     ND                3.0
# 2806     ND                2.5
# 2807     IA                3.8
# 2808     TX                4.0
# 2809     SD                3.7
# 2810     CO                4.6
# 2811     SD                3.6
# 2812     ND                2.3
# 2813     ID                6.4
# 2814     TX                5.5
# 2815     ND                3.4
# 2816     NE                3.9
# 2817     TX                6.7
# 2818     IN                8.3
# 2819     MS                7.6
# 2820     SD                3.1
# 2821     OK                3.3
# 2822     MS                9.4
#
# [2823 rows x 25 columns]

# %%
crime_rate_joined_df.to_csv('crime_rate_year_2013',index=False)

# %%
from sqlalchemy import create_engine
import pymysql, os
pymysql.install_as_MySQLdb()

# %%
PASSWD = os.getenv("LOCAL_MYSQL_PASS")
USER = "root"
PORT = "3306"
DOMAIN = "localhost"
DB = "prj_unemployment"

# %%
engine = create_engine(f"mysql://{USER}:{PASSWD}@{DOMAIN}:{PORT}/{DB}")
conn = engine.connect()

# %%
crime_rate_joined_df.to_sql(name='crime_rate_year_2013', con=engine, if_exists='append', index=False)
